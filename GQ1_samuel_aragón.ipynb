# %%
import random
import os
def run():

    IMAGES = ['''
  +---+
  |   |
      |
      |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========''']


    DB = [
        "AMERICA",
        "OCEANIA",
        "ASIA",
        "AFRICA" ,
        "EUROPA",
    ]

    word = random.choice(DB)
    spaces = ["_"] * len(word)
    attemps = 6

    while True:
        os.system('cls')
        for character in spaces:
            print(character, end="")
        print(IMAGES[attemps])
        letter = input("Puedes adivinar el continente?\nElige una letra: ").upper()

        found = False
        for idx, character in enumerate(word):
            if character == letter:
                spaces[idx] = letter
                found = True
        
        if  not found:
            attemps -= 1


        if "_" not in spaces:
            os.system('cls')
            print("Ganaste")
            break 
            

        if attemps == 0:
            os.system('cls')
            print("Perdiste")
            break
        







if __name__=="__main__":
    run()
# Out:
# ______
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# ...
# Puedes adivinar el continente?
# Elige una letra: e
# E_____
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# ...
# Puedes adivinar el continente?
# Elige una letra: g
# E_____
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# ...
# Puedes adivinar el continente?
# Elige una letra: a
# E____A
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# ...
# Puedes adivinar el continente?
# Elige una letra: u
# EU___A
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# ...
# Puedes adivinar el continente?
# Elige una letra: r
# EUR__A
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# ...
# Puedes adivinar el continente?
# Elige una letra: o
# EURO_A
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# ...
# Puedes adivinar el continente?
# Elige una letra: p
# Ganaste
